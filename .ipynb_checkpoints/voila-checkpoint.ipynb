# %%
import pandas as pd
import re
from pandas import json_normalize
from sklearn.cluster import KMeans
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.cluster import KMeans

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
songs = pd.read_csv('songs.csv')

# %%
df_with_audiof = pd.read_csv('df_with_audiof.csv')

# %%
X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %%
def get_cluster_from_imput(x):
    search_results = sp.search(q=x, limit=1)
    song_id = search_results['tracks']['items'][0]['id']
    audio_features = sp.audio_features(song_id)
    audio_features_df = json_normalize(audio_features)
    X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
    # print('X', X)
    X_scaled = scaler.transform(X)
    # print('X_scaled', X_scaled)
    cluster = kmeans.predict(X_scaled)
    return cluster[0]

# %%
def pick_one_random_song(x):
    filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]
    random_row = filtered_df.sample(n=1, random_state=random.seed())
    return random_row

# %%
kmeans = KMeans(n_clusters=15, random_state=42)  
kmeans.fit(X_scaled)
# Out:
# /Users/v.adragna/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=15, random_state=42)

# %%
get_cluster_from_imput('When I Was Your Man')
# Out:
# 1

# %%
max_characters = 100
pd.set_option("display.max_colwidth", max_characters)

user_input = input("Tell me a song you like: ")
user_input = user_input.lower()


from IPython.display import Image, display

if user_input in songs['title'].values:
    suggested_titles = songs[songs['title'] != user_input]['title']
    if not suggested_titles.empty:
        print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])
else:
    search_results = sp.search(q=user_input, limit=10)
    song_info = search_results['tracks']['items'][0]['artists'][0]['name']
    print("I am going to search similar songs to " + user_input + " from " + search_results['tracks']['items'][0]['artists'][0]['name'])
    imput_cluster = get_cluster_from_imput(user_input)
    random_row = pick_one_random_song(imput_cluster)
    print('You might also like ' + random_row['track.name'] + ' by ' + random_row['name'])
    spotify_track_url = 'https://open.spotify.com/track/' + random_row['song_id']
    print("link: ", spotify_track_url)
    artist_info = sp.search(q=random_row['name'], type='artist', limit=1)
    image_url = artist_info['artists']['items'][0]['images'][0]['url']
    display(Image(url=image_url))
# Out:
# Tell me a song you like:  mamma mia
# I am going to search similar songs to mamma mia from ABBA
# 6976    You might also like Love Generation - Radio Edit by Various Artists
# dtype: object
# link:  6976    https://open.spotify.com/track/3s3DWOPtKQSgJVDRKu85Tt
# Name: song_id, dtype: object
# <img src="https://i.scdn.co/image/ab6761610000e5eb7f5cc432c9c109248ebec1ac"/>

# %%
# !pip install voila

# %%
# !voila Voila.ipynb --debug
# Out:
# [Voila] Looking for voila in /etc/jupyter
# [Voila] Looking for voila in /usr/local/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/anaconda3/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/.local/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/.jupyter
# [Voila] Looking for voila in /Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project
# [Voila] using template: lab
# [Voila] template paths:
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base
# 	/Users/v.adragna/Library/Jupyter
# 	/Users/v.adragna/Library/Jupyter/voila/templates
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates
# 	/Users/v.adragna/.local/share/jupyter
# 	/Users/v.adragna/.local/share/jupyter/voila/templates
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates
# 	/Users/v.adragna/anaconda3/share/jupyter
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates
# 	/usr/local/share/jupyter
# 	/usr/local/share/jupyter/voila/templates
# 	/usr/local/share/jupyter/nbconvert/templates
# 	/usr/share/jupyter
# 	/usr/share/jupyter/voila/templates
# 	/usr/share/jupyter/nbconvert/templates
# [Voila] static paths:
# 	/Users/v.adragna/Library/Jupyter/voila/templates/lab/static
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/.local/share/jupyter/voila/templates/lab/static
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab/static
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab/static
# 	/usr/local/share/jupyter/voila/templates/lab/static
# 	/usr/local/share/jupyter/nbconvert/templates/lab/static
# 	/usr/share/jupyter/voila/templates/lab/static
# 	/usr/share/jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/Library/Jupyter/voila/templates/base/static
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/.local/share/jupyter/voila/templates/base/static
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base/static
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base/static
# 	/usr/local/share/jupyter/voila/templates/base/static
# 	/usr/local/share/jupyter/nbconvert/templates/base/static
# 	/usr/share/jupyter/voila/templates/base/static
# 	/usr/share/jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/static
# [Voila] Using /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T to store connection files
# [Voila] Storing connection files in /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/voila_e6uw_uwp.
# [Voila] Serving static files from /Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/static.
# [Voila] Voilà is running at:
# http://localhost:8866/
# [Voila] WARNING | Clearing invalid/expired login cookie username-localhost-8866
# [Voila] Generating new user for token-authenticated request: e24948f10b3c4ba290f22dd0e781d0ea
# [Voila] Paths used for configuration of page_config:
# 	/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/usr/local/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/anaconda3/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/.local/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/.jupyter/labconfig/page_config.json
# [Voila] Found kernel python3 in /Users/v.adragna/anaconda3/share/jupyter/kernels
# [Voila] Instantiating kernel 'Python 3 (ipykernel)' with kernel provisioner: local-provisioner
# [Voila] Starting kernel: ['/Users/v.adragna/anaconda3/bin/python', '-m', 'ipykernel_launcher', '-f', '/private/var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/voila_e6uw_uwp/kernel-de9d50d4-2601-48f2-aba6-f944d1a827de.json']
# [Voila] Connecting to: tcp://127.0.0.1:64222
# [Voila] WARNING | Clearing invalid/expired login cookie username-localhost-8866
# [Voila] Generating new user for token-authenticated request: 0747d939f2df4da5bd39bbccd640b655
# 404 GET /api/kernels/c0de6e00-aeee-4687-baac-d4cc80307103?1694170467960 (::1): Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103
# [Voila] WARNING | wrote error: 'Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103'
# Traceback (most recent call last):
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/tornado/web.py", line 1786, in _execute
#     result = await result
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/services/kernels/handlers.py", line 73, in get
#     model = await ensure_async(km.kernel_model(kernel_id))
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/services/kernels/kernelmanager.py", line 501, in kernel_model
#     self._check_kernel_id(kernel_id)
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/services/kernels/kernelmanager.py", line 532, in _check_kernel_id
#     raise web.HTTPError(404, "Kernel does not exist: %s" % kernel_id)
# tornado.web.HTTPError: HTTP 404: Not Found (Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103)
# 404 GET /api/kernels/c0de6e00-aeee-4687-baac-d4cc80307103?1694170467960 (::1) 12.05ms
# [Voila] Connecting to: tcp://127.0.0.1:64219
# [Voila] Kernel started: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Kernel args: {'kernel_name': 'python3', 'env': {'SHELL': '/bin/zsh', 'TMPDIR': '/var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/', 'CONDA_SHLVL': '1', 'CONDA_PROMPT_MODIFIER': '(base) ', 'LC_ALL': 'en_US.UTF-8', 'USER': 'v.adragna', 'COMMAND_MODE': 'unix2003', 'CONDA_EXE': '/Users/v.adragna/anaconda3/bin/conda', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.d6XFS8FmeG/Listeners', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x4', '_CE_CONDA': '', 'CONDA_ROOT': '/Users/v.adragna/anaconda3', 'PATH': '/Users/v.adragna/anaconda3/bin:/Users/v.adragna/anaconda3/condabin:/usr/bin:/bin:/usr/sbin:/sbin', 'CONDA_PREFIX': '/Users/v.adragna/anaconda3', '__CFBundleIdentifier': 'com.anaconda.io', 'PWD': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project', 'LANG': 'en_US.UTF-8', 'EVENT_NOKQUEUE': '1', 'XPC_FLAGS': '0x0', '_CE_M': '', 'XPC_SERVICE_NAME': '0', 'SHLVL': '1', 'HOME': '/Users/v.adragna', 'CONDA_PYTHON_EXE': '/Users/v.adragna/anaconda3/bin/python', 'LOGNAME': 'v.adragna', 'LC_CTYPE': 'UTF-8', 'CONDA_DEFAULT_ENV': 'base', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'JPY_SESSION_NAME': 'Desktop/IH-Labs/Week6/gnod_project/fa315e53-114d-4d61-9160-7ec5181f4488', 'JPY_PARENT_PID': '12772', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'OLDPWD': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project', '_': '/Users/v.adragna/anaconda3/bin/voila', <ENV_VARIABLE.SCRIPT_NAME: 'SCRIPT_NAME'>: '/', <ENV_VARIABLE.PATH_INFO: 'PATH_INFO'>: '', <ENV_VARIABLE.QUERY_STRING: 'QUERY_STRING'>: '', <ENV_VARIABLE.SERVER_SOFTWARE: 'SERVER_SOFTWARE'>: 'voila/0.5.2', <ENV_VARIABLE.SERVER_PROTOCOL: 'SERVER_PROTOCOL'>: 'HTTP/1.1', <ENV_VARIABLE.SERVER_PORT: 'SERVER_PORT'>: '8866', <ENV_VARIABLE.SERVER_NAME: 'SERVER_NAME'>: 'localhost', <ENV_VARIABLE.VOILA_PREHEAT: 'VOILA_PREHEAT'>: 'False', <ENV_VARIABLE.VOILA_BASE_URL: 'VOILA_BASE_URL'>: '/', <ENV_VARIABLE.VOILA_SERVER_URL: 'VOILA_SERVER_URL'>: '/', <ENV_VARIABLE.VOILA_REQUEST_URL: 'VOILA_REQUEST_URL'>: 'http://localhost:8866/', <ENV_VARIABLE.VOILA_APP_PORT: 'VOILA_APP_PORT'>: '8866'}, 'cwd': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project'}
# [Voila] Template paths:
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base
# 	/Users/v.adragna/Library/Jupyter
# 	/Users/v.adragna/Library/Jupyter/voila/templates
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates
# 	/Users/v.adragna/.local/share/jupyter
# 	/Users/v.adragna/.local/share/jupyter/voila/templates
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates
# 	/Users/v.adragna/anaconda3/share/jupyter
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates
# 	/usr/local/share/jupyter
# 	/usr/local/share/jupyter/voila/templates
# 	/usr/local/share/jupyter/nbconvert/templates
# 	/usr/share/jupyter
# 	/usr/share/jupyter/voila/templates
# 	/usr/share/jupyter/nbconvert/templates
# [Voila] Applying preprocessor: TagRemovePreprocessor
# [Voila] Applying preprocessor: RegexRemovePreprocessor
# [Voila] Applying preprocessor: coalesce_streams
# [Voila] Applying preprocessor: HighlightMagicsPreprocessor
# [Voila] Applying preprocessor: CSSHTMLHeaderPreprocessor
# [Voila] Attempting to load template index.html.j2
# [Voila]     template_paths: /Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab:/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base:/Users/v.adragna/Library/Jupyter:/Users/v.adragna/Library/Jupyter/voila/templates:/Users/v.adragna/Library/Jupyter/nbconvert/templates:/Users/v.adragna/.local/share/jupyter:/Users/v.adragna/.local/share/jupyter/voila/templates:/Users/v.adragna/.local/share/jupyter/nbconvert/templates:/Users/v.adragna/anaconda3/share/jupyter:/Users/v.adragna/anaconda3/share/jupyter/voila/templates:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates:/usr/local/share/jupyter:/usr/local/share/jupyter/voila/templates:/usr/local/share/jupyter/nbconvert/templates:/usr/share/jupyter:/usr/share/jupyter/voila/templates:/usr/share/jupyter/nbconvert/templates
# [Voila] connecting iopub channel to tcp://127.0.0.1:64219
# [Voila] Connecting to: tcp://127.0.0.1:64219
# [Voila] connecting shell channel to tcp://127.0.0.1:64218
# [Voila] Connecting to: tcp://127.0.0.1:64218
# [Voila] connecting stdin channel to tcp://127.0.0.1:64220
# [Voila] Connecting to: tcp://127.0.0.1:64220
# [Voila] connecting heartbeat channel to tcp://127.0.0.1:64221
# [Voila] connecting control channel to tcp://127.0.0.1:64222
# [Voila] Connecting to: tcp://127.0.0.1:64222
# 404 POST /voila/api/shutdown/c0de6e00-aeee-4687-baac-d4cc80307103 (::1): Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103
# [Voila] WARNING | wrote error: 'Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103'
# Traceback (most recent call last):
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/tornado/web.py", line 1786, in _execute
#     result = await result
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/shutdown_kernel_handler.py", line 11, in post
#     await ensure_async(self.kernel_manager.shutdown_kernel(kernel_id))
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_core/utils/__init__.py", line 182, in ensure_async
#     result = await obj
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/services/kernels/kernelmanager.py", line 418, in _async_shutdown_kernel
#     self._check_kernel_id(kernel_id)
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/services/kernels/kernelmanager.py", line 532, in _check_kernel_id
#     raise web.HTTPError(404, "Kernel does not exist: %s" % kernel_id)
# tornado.web.HTTPError: HTTP 404: Not Found (Kernel does not exist: c0de6e00-aeee-4687-baac-d4cc80307103)
# 404 POST /voila/api/shutdown/c0de6e00-aeee-4687-baac-d4cc80307103 (::1) 20.96ms
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (starting)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] Executing cell:
# import pandas as pd
# import re
# from pandas import json_normalize
# from sklearn.cluster import KMeans
# from sklearn import cluster, datasets
# from sklearn.preprocessing import StandardScaler
# from matplotlib.lines import Line2D
# import random
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials
# from sklearn.cluster import KMeans
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'import pandas as pd\nimport re\nfrom pandas import json_normalize\nfrom sklearn.cluster import KMeans\nfrom sklearn import cluster, datasets\nfrom sklearn.preprocessing import StandardScaler\nfrom matplotlib.lines import Line2D\nimport random\nimport spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nfrom sklearn.cluster import KMeans', 'execution_count': 1}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# # !pip install spotipy
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': '# !pip install spotipy', 'execution_count': 2}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials', 'execution_count': 3}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# secrets_file = open("secrets.txt","r")
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'secrets_file = open("secrets.txt","r")', 'execution_count': 4}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# string = secrets_file.read()
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'string = secrets_file.read()', 'execution_count': 5}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# secrets_dict={}
# for line in string.split('\n'):
#     if len(line) > 0:
#         #print(line.split(':'))
#         secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "secrets_dict={}\nfor line in string.split('\\n'):\n    if len(line) > 0:\n        #print(line.split(':'))\n        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()", 'execution_count': 6}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
#                                                            client_secret=secrets_dict['clientsecret']))
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],\n                                                           client_secret=secrets_dict['clientsecret']))", 'execution_count': 7}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# songs = pd.read_csv('songs.csv')
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "songs = pd.read_csv('songs.csv')", 'execution_count': 8}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# df_with_audiof = pd.read_csv('df_with_audiof.csv')
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "df_with_audiof = pd.read_csv('df_with_audiof.csv')", 'execution_count': 9}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]", 'execution_count': 10}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler().fit(X)
# X_scaled = scaler.transform(X)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler().fit(X)\nX_scaled = scaler.transform(X)', 'execution_count': 11}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# def get_cluster_from_imput(x):
#     search_results = sp.search(q=x, limit=1)
#     song_id = search_results['tracks']['items'][0]['id']
#     audio_features = sp.audio_features(song_id)
#     audio_features_df = json_normalize(audio_features)
#     X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
#     # print('X', X)
#     X_scaled = scaler.transform(X)
#     # print('X_scaled', X_scaled)
#     cluster = kmeans.predict(X_scaled)
#     return cluster[0]
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "def get_cluster_from_imput(x):\n    search_results = sp.search(q=x, limit=1)\n    song_id = search_results['tracks']['items'][0]['id']\n    audio_features = sp.audio_features(song_id)\n    audio_features_df = json_normalize(audio_features)\n    X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]\n    # print('X', X)\n    X_scaled = scaler.transform(X)\n    # print('X_scaled', X_scaled)\n    cluster = kmeans.predict(X_scaled)\n    return cluster[0]", 'execution_count': 12}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# def pick_one_random_song(x):
#     filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]
#     random_row = filtered_df.sample(n=1, random_state=random.seed())
#     return random_row
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "def pick_one_random_song(x):\n    filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]\n    random_row = filtered_df.sample(n=1, random_state=random.seed())\n    return random_row", 'execution_count': 13}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# kmeans = KMeans(n_clusters=15, random_state=42)
# kmeans.fit(X_scaled)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'kmeans = KMeans(n_clusters=15, random_state=42)  \nkmeans.fit(X_scaled)', 'execution_count': 14}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stderr', 'text': "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning\n  warnings.warn(\n"}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_result
# [Voila] msg_type: execute_result
# [Voila] content: {'data': {'text/plain': 'KMeans(n_clusters=15, random_state=42)', 'text/html': '<style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-color: white;}#sk-container-id-1 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-1 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-1 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-1 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-1 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-1 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-1 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-width: 100%;overflow: auto;}#sk-container-id-1 input.sk-toggleable__control:checked~label.sk-toggleable__label-arrow:before {content: "▾";}#sk-container-id-1 div.sk-estimator input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-label input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 input.sk-hidden--visually {border: 0;clip: rect(1px 1px 1px 1px);clip: rect(1px, 1px, 1px, 1px);height: 1px;margin: -1px;overflow: hidden;padding: 0;position: absolute;width: 1px;}#sk-container-id-1 div.sk-estimator {font-family: monospace;background-color: #f0f8ff;border: 1px dotted black;border-radius: 0.25em;box-sizing: border-box;margin-bottom: 0.5em;}#sk-container-id-1 div.sk-estimator:hover {background-color: #d4ebff;}#sk-container-id-1 div.sk-parallel-item::after {content: "";width: 100%;border-bottom: 1px solid gray;flex-grow: 1;}#sk-container-id-1 div.sk-label:hover label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-serial::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: 0;}#sk-container-id-1 div.sk-serial {display: flex;flex-direction: column;align-items: center;background-color: white;padding-right: 0.2em;padding-left: 0.2em;position: relative;}#sk-container-id-1 div.sk-item {position: relative;z-index: 1;}#sk-container-id-1 div.sk-parallel {display: flex;align-items: stretch;justify-content: center;background-color: white;position: relative;}#sk-container-id-1 div.sk-item::before, #sk-container-id-1 div.sk-parallel-item::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: -1;}#sk-container-id-1 div.sk-parallel-item {display: flex;flex-direction: column;z-index: 1;position: relative;background-color: white;}#sk-container-id-1 div.sk-parallel-item:first-child::after {align-self: flex-end;width: 50%;}#sk-container-id-1 div.sk-parallel-item:last-child::after {align-self: flex-start;width: 50%;}#sk-container-id-1 div.sk-parallel-item:only-child::after {width: 0;}#sk-container-id-1 div.sk-dashed-wrapped {border: 1px dashed gray;margin: 0 0.4em 0.5em 0.4em;box-sizing: border-box;padding-bottom: 0.4em;background-color: white;}#sk-container-id-1 div.sk-label label {font-family: monospace;font-weight: bold;display: inline-block;line-height: 1.2em;}#sk-container-id-1 div.sk-label-container {text-align: center;}#sk-container-id-1 div.sk-container {/* jupyter\'s `normalize.less` sets `[hidden] { display: none; }` but bootstrap.min.css set `[hidden] { display: none !important; }` so we also need the `!important` here to be able to override the default hidden behavior on the sphinx rendered scikit-learn.org. See: https://github.com/scikit-learn/scikit-learn/issues/21755 */displa ...
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# get_cluster_from_imput('When I Was Your Man')
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "get_cluster_from_imput('When I Was Your Man')", 'execution_count': 15}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_result
# [Voila] msg_type: execute_result
# [Voila] content: {'data': {'text/plain': '1'}, 'metadata': {}, 'execution_count': 15}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# max_characters = 100
# pd.set_option("display.max_colwidth", max_characters)
#
# user_input = input("Tell me a song you like: ")
# user_input = user_input.lower()
#
#
# from IPython.display import Image, display
#
# if user_input in songs['title'].values:
#     suggested_titles = songs[songs['title'] != user_input]['title']
#     if not suggested_titles.empty:
#         print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])
# else:
#     search_results = sp.search(q=user_input, limit=10)
#     song_info = search_results['tracks']['items'][0]['artists'][0]['name']
#     print("I am going to search similar songs to " + user_input + " from " + search_results['tracks']['items'][0]['artists'][0]['name'])
#     imput_cluster = get_cluster_from_imput(user_input)
#     random_row = pick_one_random_song(imput_cluster)
#     print('You might also like ' + random_row['track.name'] + ' by ' + random_row['name'])
#     spotify_track_url = 'https://open.spotify.com/track/' + random_row['song_id']
#     print("link: ", spotify_track_url)
#     artist_info = sp.search(q=random_row['name'], type='artist', limit=1)
#     image_url = artist_info['artists']['items'][0]['images'][0]['url']
#     display(Image(url=image_url))
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'max_characters = 100\npd.set_option("display.max_colwidth", max_characters)\n\nuser_input = input("Tell me a song you like: ")\nuser_input = user_input.lower()\n\n\nfrom IPython.display import Image, display\n\nif user_input in songs[\'title\'].values:\n    suggested_titles = songs[songs[\'title\'] != user_input][\'title\']\n    if not suggested_titles.empty:\n        print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])\nelse:\n    search_results = sp.search(q=user_input, limit=10)\n    song_info = search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\']\n    print("I am going to search similar songs to " + user_input + " from " + search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\'])\n    imput_cluster = get_cluster_from_imput(user_input)\n    random_row = pick_one_random_song(imput_cluster)\n    print(\'You might also like \' + random_row[\'track.name\'] + \' by \' + random_row[\'name\'])\n    spotify_track_url = \'https://open.spotify.com/track/\' + random_row[\'song_id\']\n    print("link: ", spotify_track_url)\n    artist_info = sp.search(q=random_row[\'name\'], type=\'artist\', limit=1)\n    image_url = artist_info[\'artists\'][\'items\'][0][\'images\'][0][\'url\']\n    display(Image(url=image_url))', 'execution_count': 16}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: error
# [Voila] msg_type: error
# [Voila] content: {'traceback': ['\x1b---------------------------------------------------------------------------\x1b', '\x1bStdinNotImplementedError\x1b                  Traceback (most recent call last)', 'Cell \x1bIn[16], line 4\x1b\n\x1b      1\x1b max_characters \x1b=\x1b \x1b100\x1b\n\x1b      2\x1b pd\x1b.\x1bset_option(\x1b"\x1b\x1bdisplay.max_colwidth\x1b\x1b"\x1b, max_characters)\n\x1b----> 4\x1b user_input \x1b=\x1b \x1binput\x1b\x1b(\x1b\x1b"\x1b\x1bTell me a song you like: \x1b\x1b"\x1b\x1b)\x1b\n\x1b      5\x1b user_input \x1b=\x1b user_input\x1b.\x1blower()\n\x1b      8\x1b \x1bfrom\x1b \x1bIPython\x1b\x1b.\x1b\x1bdisplay\x1b \x1bimport\x1b Image, display\n', 'File \x1b~/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py:1172\x1b, in \x1bKernel.raw_input\x1b(self, prompt)\x1b\n\x1b   1165\x1b \x1b"""Forward raw_input to frontends\x1b\n\x1b   1166\x1b \n\x1b   1167\x1b \x1bRaises\x1b\n\x1b   1168\x1b \x1b------\x1b\n\x1b   1169\x1b \x1bStdinNotImplementedError if active frontend doesn\'t support stdin.\x1b\n\x1b   1170\x1b \x1b"""\x1b\n\x1b   1171\x1b \x1bif\x1b \x1bnot\x1b \x1bself\x1b\x1b.\x1b_allow_stdin:\n\x1b-> 1172\x1b     \x1braise\x1b StdinNotImplementedError(\n\x1b   1173\x1b         \x1b"\x1b\x1braw_input was called, but this frontend does not support input requests.\x1b\x1b"\x1b\n\x1b   1174\x1b     )\n\x1b   1175\x1b \x1breturn\x1b \x1bself\x1b\x1b.\x1b_input_request(\n\x1b   1176\x1b     \x1bstr\x1b(prompt),\n\x1b   1177\x1b     \x1bself\x1b\x1b.\x1b_parent_ident[\x1b"\x1b\x1bshell\x1b\x1b"\x1b[39m],\n\x1b   1178\x1b     \x1bself\x1b\x1b.\x1bget_parent(\x1b"\x1b\x1bshell\x1b\x1b"\x1b),\n\x1b   1179\x1b     password\x1b=\x1b\x1bFalse\x1b,\n\x1b   1180\x1b )\n', '\x1bStdinNotImplementedError\x1b: raw_input was called, but this frontend does not support input requests.'], 'ename': 'StdinNotImplementedError', 'evalue': 'raw_input was called, but this frontend does not support input requests.'}
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] ERROR | Error at server while executing cell: {'cell_type': 'code', 'execution_count': 16, 'id': '3fa570df-d00f-46d7-a566-26986d55414f', 'metadata': {'trusted': True, 'execution': {'iopub.status.busy': '2023-09-08T10:54:40.274487Z', 'iopub.execute_input': '2023-09-08T10:54:40.275438Z', 'shell.execute_reply': '2023-09-08T10:54:41.719596Z', 'iopub.status.idle': '2023-09-08T10:54:41.721970Z'}}, 'outputs': [{'output_type': 'error', 'ename': 'StdinNotImplementedError', 'evalue': 'raw_input was called, but this frontend does not support input requests.', 'traceback': ['\x1b---------------------------------------------------------------------------\x1b', '\x1bStdinNotImplementedError\x1b                  Traceback (most recent call last)', 'Cell \x1bIn[16], line 4\x1b\n\x1b      1\x1b max_characters \x1b=\x1b \x1b100\x1b\n\x1b      2\x1b pd\x1b.\x1bset_option(\x1b"\x1b\x1bdisplay.max_colwidth\x1b\x1b"\x1b, max_characters)\n\x1b----> 4\x1b user_input \x1b=\x1b \x1binput\x1b\x1b(\x1b\x1b"\x1b\x1bTell me a song you like: \x1b\x1b"\x1b\x1b)\x1b\n\x1b      5\x1b user_input \x1b=\x1b user_input\x1b.\x1blower()\n\x1b      8\x1b \x1bfrom\x1b \x1bIPython\x1b\x1b.\x1b\x1bdisplay\x1b \x1bimport\x1b Image, display\n', 'File \x1b~/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py:1172\x1b, in \x1bKernel.raw_input\x1b(self, prompt)\x1b\n\x1b   1165\x1b \x1b"""Forward raw_input to frontends\x1b\n\x1b   1166\x1b \n\x1b   1167\x1b \x1bRaises\x1b\n\x1b   1168\x1b \x1b------\x1b\n\x1b   1169\x1b \x1bStdinNotImplementedError if active frontend doesn\'t support stdin.\x1b\n\x1b   1170\x1b \x1b"""\x1b\n\x1b   1171\x1b \x1bif\x1b \x1bnot\x1b \x1bself\x1b\x1b.\x1b_allow_stdin:\n\x1b-> 1172\x1b     \x1braise\x1b StdinNotImplementedError(\n\x1b   1173\x1b         \x1b"\x1b\x1braw_input was called, but this frontend does not support input requests.\x1b\x1b"\x1b\n\x1b   1174\x1b     )\n\x1b   1175\x1b \x1breturn\x1b \x1bself\x1b\x1b.\x1b_input_request(\n\x1b   1176\x1b     \x1bstr\x1b(prompt),\n\x1b   1177\x1b     \x1bself\x1b\x1b.\x1b_parent_ident[\x1b"\x1b\x1bshell\x1b\x1b"\x1b[39m],\n\x1b   1178\x1b     \x1bself\x1b\x1b.\x1bget_parent(\x1b"\x1b\x1bshell\x1b\x1b"\x1b),\n\x1b   1179\x1b     password\x1b=\x1b\x1bFalse\x1b,\n\x1b   1180\x1b )\n', '\x1bStdinNotImplementedError\x1b: raw_input was called, but this frontend does not support input requests.']}], 'source': 'max_characters = 100\npd.set_option("display.max_colwidth", max_characters)\n\nuser_input = input("Tell me a song you like: ")\nuser_input = user_input.lower()\n\n\nfrom IPython.display import Image, display\n\nif user_input in songs[\'title\'].values:\n    suggested_titles = songs[songs[\'title\'] != user_input][\'title\']\n    if not suggested_titles.empty:\n        print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])\nelse:\n    search_results = sp.search(q=user_input, limit=10)\n    song_info = search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\']\n    print("I am going to search similar songs to " + user_input + " from " + search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\'])\n    imput_cluster = get_cluster_from_imput(user_input)\n    random_row = pick_one_random_song(imput_cluster)\n    print(\'You might also like \' + random_row[\'track.name\'] + \' by \' + random_row[\'name\'])\n    spotify_track_url = \'https://open.spotify.com/track/\' + random_row[\'song_id\']\n    print("link: ", spotify_track_url)\n    artist_info = sp.search(q=random_row[\'name\'], type=\'artist\', limit=1)\n    image_url = artist_info[\'artists\'][\'items\'][0][\'images\'][0][\'url\']\n    display(Image(url=image_url))'}
# Traceback (most recent call last):
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/notebook_renderer.py", line 261, in _jinja_cell_generator
#     output_cell = await self.executor.execute_cell(
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/execute.py", line 68, in execute_cell
#     result = await self.async_execute_cell(cell, cell_index, store_history)
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/nbclient/client.py", line 965, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/nbclient/client.py", line 862, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# max_characters = 100
# pd.set_option("display.max_colwidth", max_characters)
#
# user_input = input("Tell me a song you like: ")
# user_input = user_input.lower()
#
#
# from IPython.display import Image, display
#
# if user_input in songs['title'].values:
#     suggested_titles = songs[songs['title'] != user_input]['title']
#     if not suggested_titles.empty:
#         print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])
# else:
#     search_results = sp.search(q=user_input, limit=10)
#     song_info = search_results['tracks']['items'][0]['artists'][0]['name']
#     print("I am going to search similar songs to " + user_input + " from " + search_results['tracks']['items'][0]['artists'][0]['name'])
#     imput_cluster = get_cluster_from_imput(user_input)
#     random_row = pick_one_random_song(imput_cluster)
#     print('You might also like ' + random_row['track.name'] + ' by ' + random_row['name'])
#     spotify_track_url = 'https://open.spotify.com/track/' + random_row['song_id']
#     print("link: ", spotify_track_url)
#     artist_info = sp.search(q=random_row['name'], type='artist', limit=1)
#     image_url = artist_info['artists']['items'][0]['images'][0]['url']
#     display(Image(url=image_url))
# ------------------
#
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[16], line 4
#       1 max_characters = 100
#       2 pd.set_option("display.max_colwidth", max_characters)
# ----> 4 user_input = input("Tell me a song you like: ")
#       5 user_input = user_input.lower()
#       8 from IPython.display import Image, display
#
# File ~/anaconda3/lib/python3.10/site-packages/ipykernel/kernelbase.py:1172, in Kernel.raw_input(self, prompt)
#    1165 """Forward raw_input to frontends
#    1166
#    1167 Raises
#    1168 ------
#    1169 StdinNotImplementedError if active frontend doesn't support stdin.
#    1170 """
#    1171 if not self._allow_stdin:
# -> 1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
#    1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
#
# [Voila] Path @pyviz/jupyterlab_pyviz/static/remoteEntry.c267118552c4161d6406.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@pyviz/jupyterlab_pyviz/static/remoteEntry.c267118552c4161d6406.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/remoteEntry.ca1efc27dc965162ca86.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/remoteEntry.ca1efc27dc965162ca86.js
# [Voila] Path jupyterlab-plotly/static/remoteEntry.66500334d7b36213676e.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/jupyterlab-plotly/static/remoteEntry.66500334d7b36213676e.js
# [Voila] Path jupyterlab-plotly/static/133.abf92d63193737cdd014.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/jupyterlab-plotly/static/133.abf92d63193737cdd014.js
# [Voila] Path jupyterlab-plotly/static/423.13b35dff1663e01b2912.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/jupyterlab-plotly/static/423.13b35dff1663e01b2912.js
# [Voila] Path @pyviz/jupyterlab_pyviz/static/979.b175a7785a2d666802fa.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@pyviz/jupyterlab_pyviz/static/979.b175a7785a2d666802fa.js
# [Voila] Path @pyviz/jupyterlab_pyviz/static/534.20c70d4645cf38a0db5b.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@pyviz/jupyterlab_pyviz/static/534.20c70d4645cf38a0db5b.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/638.f3e5e34a28f3334d4f08.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/638.f3e5e34a28f3334d4f08.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/243.6c384ff2649ef572a18a.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/243.6c384ff2649ef572a18a.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/803.b7b75bd6e7977a648c67.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/803.b7b75bd6e7977a648c67.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/272.2a8425db7209008188fc.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/272.2a8425db7209008188fc.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/18.5fbcd9c56ded92ea9df9.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/18.5fbcd9c56ded92ea9df9.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/279.aa88a78c8bf62c65db54.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/279.aa88a78c8bf62c65db54.js
# [Voila] Path @jupyter-widgets/jupyterlab-manager/static/523.fa256ee012d38a89b65a.js served from /Users/v.adragna/anaconda3/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static/523.fa256ee012d38a89b65a.js
# [Voila] Requesting kernel info from de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Connecting to: tcp://127.0.0.1:64218
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] Received kernel info: {'status': 'ok', 'protocol_version': '5.3', 'implementation': 'ipython', 'implementation_version': '8.10.0', 'language_info': {'name': 'python', 'version': '3.10.9', 'mimetype': 'text/x-python', 'codemirror_mode': {'name': 'ipython', 'version': 3}, 'pygments_lexer': 'ipython3', 'nbconvert_exporter': 'python', 'file_extension': '.py'}, 'banner': "Python 3.10.9 (main, Mar  1 2023, 12:33:47) [Clang 14.0.6 ]\nType 'copyright', 'credits' or 'license' for more information\nIPython 8.10.0 -- An enhanced Interactive Python. Type '?' for help.\n", 'help_links': [{'text': 'Python Reference', 'url': 'https://docs.python.org/3.10'}, {'text': 'IPython Reference', 'url': 'https://ipython.org/documentation.html'}, {'text': 'NumPy Reference', 'url': 'https://docs.scipy.org/doc/numpy/reference/'}, {'text': 'SciPy Reference', 'url': 'https://docs.scipy.org/doc/scipy/reference/'}, {'text': 'Matplotlib Reference', 'url': 'https://matplotlib.org/contents.html'}, {'text': 'SymPy Reference', 'url': 'http://docs.sympy.org/latest/index.html'}, {'text': 'pandas Reference', 'url': 'https://pandas.pydata.org/pandas-docs/stable/'}]}
# [Voila] Opening websocket /api/kernels/de9d50d4-2601-48f2-aba6-f944d1a827de/channels
# [Voila] Connecting to kernel de9d50d4-2601-48f2-aba6-f944d1a827de.
# [Voila] Getting buffer for de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Connecting to: tcp://127.0.0.1:64219
# [Voila] Connecting to: tcp://127.0.0.1:64218
# [Voila] Connecting to: tcp://127.0.0.1:64222
# [Voila] Connecting to: tcp://127.0.0.1:64220
# [Voila] Connecting to: tcp://127.0.0.1:64218
# [Voila] Connecting to: tcp://127.0.0.1:64222
# [Voila] Nudge: attempt 1 on kernel de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] Nudge: IOPub received: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Nudge: resolving iopub future: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] Nudge: shell info reply received: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Nudge: resolving shell future: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] Nudge: control info reply received: de9d50d4-2601-48f2-aba6-f944d1a827de
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: stream
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: comm_close
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: stream
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (busy)
# [Voila] activity on de9d50d4-2601-48f2-aba6-f944d1a827de: status (idle)
