# %%
import pandas as pd
import re
from pandas import json_normalize
from sklearn.cluster import KMeans
from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
import random
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.cluster import KMeans

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
songs = pd.read_csv('songs.csv')

# %%
df_with_audiof = pd.read_csv('df_with_audiof.csv')

# %%
X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %%
def get_cluster_from_imput(x):
    search_results = sp.search(q=x, limit=1)
    song_id = search_results['tracks']['items'][0]['id']
    audio_features = sp.audio_features(song_id)
    audio_features_df = json_normalize(audio_features)
    X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
    # print('X', X)
    X_scaled = scaler.transform(X)
    # print('X_scaled', X_scaled)
    cluster = kmeans.predict(X_scaled)
    return cluster[0]

# %%
def pick_one_random_song(x):
    filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]
    random_row = filtered_df.sample(n=1, random_state=random.seed())
    return random_row

# %%
kmeans = KMeans(n_clusters=15, random_state=42)  
kmeans.fit(X_scaled)
# Out:
# /Users/v.adragna/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=15, random_state=42)

# %%
get_cluster_from_imput('When I Was Your Man')
# Out:
# 1

# %%
from ipywidgets import widgets

# %%
submit_button = widgets.Button(description="Submit")

# %%
from ipywidgets import interact, widgets
from IPython.display import Image, display

max_characters = 100
pd.set_option("display.max_colwidth", max_characters)

def handle_user_input(user_input):
    user_input = user_input.lower()
    
    if user_input in songs['title'].values:
        suggested_titles = songs[songs['title'] != user_input]['title']
        if not suggested_titles.empty:
            print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])
    else:
        search_results = sp.search(q=user_input, limit=10)
        song_info = search_results['tracks']['items'][0]['artists'][0]['name']
        print("I am going to search similar songs to " + user_input + " from " + search_results['tracks']['items'][0]['artists'][0]['name'])
        imput_cluster = get_cluster_from_imput(user_input)
        random_row = pick_one_random_song(imput_cluster)
        print('You might also like ' + random_row['track.name'] + ' by ' + random_row['name'])
        spotify_track_url = 'https://open.spotify.com/track/' + random_row['song_id']
        print("link: ", spotify_track_url)
        artist_info = sp.search(q=random_row['name'], type='artist', limit=1)
        image_url = artist_info['artists']['items'][0]['images'][0]['url']
        display(Image(url=image_url))

    text_input.value = ""

text_input = widgets.Text(description="Search")
text_input.layout.width = '800px' 

from ipywidgets import widgets

submit_button = widgets.Button(description="Submit")

def on_submit_button_click(b):
    user_input = text_input.value
    handle_user_input(user_input)

submit_button.on_click(on_submit_button_click)
text_input.on_submit(on_submit_button_click)

# Display the widgets
display(text_input)
display(submit_button)
# With these changes, the handle_user_input function will be called both when the "Submit" button is clicked and when the "Enter" key is pressed in the text input field. Additionally, the text input field will be cleared after processing.
# Out:
# Text(value='', description='Search', layout=Layout(width='800px'))
# Button(description='Submit', style=ButtonStyle())

# %%
# !pip install voila

# %%
# !voila binder.ipynb --debug
# Out:
# [Voila] Looking for voila in /etc/jupyter
# [Voila] Looking for voila in /usr/local/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/anaconda3/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/.local/etc/jupyter
# [Voila] Looking for voila in /Users/v.adragna/.jupyter
# [Voila] Looking for voila in /Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project
# [Voila] using template: lab
# [Voila] template paths:
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base
# 	/Users/v.adragna/Library/Jupyter
# 	/Users/v.adragna/Library/Jupyter/voila/templates
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates
# 	/Users/v.adragna/.local/share/jupyter
# 	/Users/v.adragna/.local/share/jupyter/voila/templates
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates
# 	/Users/v.adragna/anaconda3/share/jupyter
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates
# 	/usr/local/share/jupyter
# 	/usr/local/share/jupyter/voila/templates
# 	/usr/local/share/jupyter/nbconvert/templates
# 	/usr/share/jupyter
# 	/usr/share/jupyter/voila/templates
# 	/usr/share/jupyter/nbconvert/templates
# [Voila] static paths:
# 	/Users/v.adragna/Library/Jupyter/voila/templates/lab/static
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/.local/share/jupyter/voila/templates/lab/static
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab/static
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab/static
# 	/usr/local/share/jupyter/voila/templates/lab/static
# 	/usr/local/share/jupyter/nbconvert/templates/lab/static
# 	/usr/share/jupyter/voila/templates/lab/static
# 	/usr/share/jupyter/nbconvert/templates/lab/static
# 	/Users/v.adragna/Library/Jupyter/voila/templates/base/static
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/.local/share/jupyter/voila/templates/base/static
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base/static
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base/static
# 	/usr/local/share/jupyter/voila/templates/base/static
# 	/usr/local/share/jupyter/nbconvert/templates/base/static
# 	/usr/share/jupyter/voila/templates/base/static
# 	/usr/share/jupyter/nbconvert/templates/base/static
# 	/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/static
# [Voila] Using /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T to store connection files
# [Voila] Storing connection files in /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/voila_68qkermi.
# [Voila] Serving static files from /Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/static.
# [Voila] The port 8866 is already in use, trying another port.
# [Voila] Voilà is running at:
# http://localhost:8867/
# [Voila] WARNING | Clearing invalid/expired login cookie username-localhost-8867
# [Voila] Generating new user for token-authenticated request: d91ab34db2db4451a11232ebd8947d82
# [Voila] Paths used for configuration of page_config:
# 	/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/usr/local/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/anaconda3/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/.local/etc/jupyter/labconfig/page_config.json
# [Voila] Paths used for configuration of page_config:
# 	/Users/v.adragna/.jupyter/labconfig/page_config.json
# [Voila] Found kernel python3 in /Users/v.adragna/anaconda3/share/jupyter/kernels
# [Voila] Instantiating kernel 'Python 3 (ipykernel)' with kernel provisioner: local-provisioner
# [Voila] Starting kernel: ['/Users/v.adragna/anaconda3/bin/python', '-m', 'ipykernel_launcher', '-f', '/private/var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/voila_68qkermi/kernel-0fef46d0-93b0-4b96-a271-eb66415d4de1.json']
# [Voila] Connecting to: tcp://127.0.0.1:51645
# [Voila] Connecting to: tcp://127.0.0.1:51642
# [Voila] Kernel started: 0fef46d0-93b0-4b96-a271-eb66415d4de1
# [Voila] Kernel args: {'kernel_name': 'python3', 'env': {'SHELL': '/bin/zsh', 'TMPDIR': '/var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/', 'CONDA_SHLVL': '1', 'CONDA_PROMPT_MODIFIER': '(base) ', 'LC_ALL': 'en_US.UTF-8', 'USER': 'v.adragna', 'COMMAND_MODE': 'unix2003', 'CONDA_EXE': '/Users/v.adragna/anaconda3/bin/conda', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.d6XFS8FmeG/Listeners', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x4', '_CE_CONDA': '', 'CONDA_ROOT': '/Users/v.adragna/anaconda3', 'PATH': '/Users/v.adragna/anaconda3/bin:/Users/v.adragna/anaconda3/condabin:/usr/bin:/bin:/usr/sbin:/sbin', 'CONDA_PREFIX': '/Users/v.adragna/anaconda3', '__CFBundleIdentifier': 'com.anaconda.io', 'PWD': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project', 'LANG': 'en_US.UTF-8', 'EVENT_NOKQUEUE': '1', 'XPC_FLAGS': '0x0', '_CE_M': '', 'XPC_SERVICE_NAME': '0', 'SHLVL': '1', 'HOME': '/Users/v.adragna', 'CONDA_PYTHON_EXE': '/Users/v.adragna/anaconda3/bin/python', 'LOGNAME': 'v.adragna', 'LC_CTYPE': 'UTF-8', 'CONDA_DEFAULT_ENV': 'base', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'JPY_SESSION_NAME': 'Desktop/IH-Labs/Week6/gnod_project/248f3cef-fbfc-4f9f-a7a3-95d9a6b794ca', 'JPY_PARENT_PID': '12772', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'OLDPWD': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project', '_': '/Users/v.adragna/anaconda3/bin/voila', <ENV_VARIABLE.SCRIPT_NAME: 'SCRIPT_NAME'>: '/', <ENV_VARIABLE.PATH_INFO: 'PATH_INFO'>: '', <ENV_VARIABLE.QUERY_STRING: 'QUERY_STRING'>: '', <ENV_VARIABLE.SERVER_SOFTWARE: 'SERVER_SOFTWARE'>: 'voila/0.5.2', <ENV_VARIABLE.SERVER_PROTOCOL: 'SERVER_PROTOCOL'>: 'HTTP/1.1', <ENV_VARIABLE.SERVER_PORT: 'SERVER_PORT'>: '8867', <ENV_VARIABLE.SERVER_NAME: 'SERVER_NAME'>: 'localhost', <ENV_VARIABLE.VOILA_PREHEAT: 'VOILA_PREHEAT'>: 'False', <ENV_VARIABLE.VOILA_BASE_URL: 'VOILA_BASE_URL'>: '/', <ENV_VARIABLE.VOILA_SERVER_URL: 'VOILA_SERVER_URL'>: '/', <ENV_VARIABLE.VOILA_REQUEST_URL: 'VOILA_REQUEST_URL'>: 'http://localhost:8867/', <ENV_VARIABLE.VOILA_APP_PORT: 'VOILA_APP_PORT'>: '8867'}, 'cwd': '/Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project'}
# [Voila] Template paths:
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base
# 	/Users/v.adragna/Library/Jupyter
# 	/Users/v.adragna/Library/Jupyter/voila/templates
# 	/Users/v.adragna/Library/Jupyter/nbconvert/templates
# 	/Users/v.adragna/.local/share/jupyter
# 	/Users/v.adragna/.local/share/jupyter/voila/templates
# 	/Users/v.adragna/.local/share/jupyter/nbconvert/templates
# 	/Users/v.adragna/anaconda3/share/jupyter
# 	/Users/v.adragna/anaconda3/share/jupyter/voila/templates
# 	/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates
# 	/usr/local/share/jupyter
# 	/usr/local/share/jupyter/voila/templates
# 	/usr/local/share/jupyter/nbconvert/templates
# 	/usr/share/jupyter
# 	/usr/share/jupyter/voila/templates
# 	/usr/share/jupyter/nbconvert/templates
# [Voila] Applying preprocessor: TagRemovePreprocessor
# [Voila] Applying preprocessor: RegexRemovePreprocessor
# [Voila] Applying preprocessor: coalesce_streams
# [Voila] Applying preprocessor: HighlightMagicsPreprocessor
# [Voila] Applying preprocessor: CSSHTMLHeaderPreprocessor
# [Voila] Attempting to load template index.html.j2
# [Voila]     template_paths: /Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab:/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base:/Users/v.adragna/Library/Jupyter:/Users/v.adragna/Library/Jupyter/voila/templates:/Users/v.adragna/Library/Jupyter/nbconvert/templates:/Users/v.adragna/.local/share/jupyter:/Users/v.adragna/.local/share/jupyter/voila/templates:/Users/v.adragna/.local/share/jupyter/nbconvert/templates:/Users/v.adragna/anaconda3/share/jupyter:/Users/v.adragna/anaconda3/share/jupyter/voila/templates:/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates:/usr/local/share/jupyter:/usr/local/share/jupyter/voila/templates:/usr/local/share/jupyter/nbconvert/templates:/usr/share/jupyter:/usr/share/jupyter/voila/templates:/usr/share/jupyter/nbconvert/templates
# [Voila] connecting iopub channel to tcp://127.0.0.1:51642
# [Voila] Connecting to: tcp://127.0.0.1:51642
# [Voila] connecting shell channel to tcp://127.0.0.1:51641
# [Voila] Connecting to: tcp://127.0.0.1:51641
# [Voila] connecting stdin channel to tcp://127.0.0.1:51643
# [Voila] Connecting to: tcp://127.0.0.1:51643
# [Voila] connecting heartbeat channel to tcp://127.0.0.1:51644
# [Voila] connecting control channel to tcp://127.0.0.1:51645
# [Voila] Connecting to: tcp://127.0.0.1:51645
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (starting)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] Executing cell:
# import pandas as pd
# import re
# from pandas import json_normalize
# from sklearn.cluster import KMeans
# from sklearn import cluster, datasets
# from sklearn.preprocessing import StandardScaler
# from matplotlib.lines import Line2D
# import random
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials
# from sklearn.cluster import KMeans
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'import pandas as pd\nimport re\nfrom pandas import json_normalize\nfrom sklearn.cluster import KMeans\nfrom sklearn import cluster, datasets\nfrom sklearn.preprocessing import StandardScaler\nfrom matplotlib.lines import Line2D\nimport random\nimport spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nfrom sklearn.cluster import KMeans', 'execution_count': 1}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# # !pip install spotipy
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': '# !pip install spotipy', 'execution_count': 2}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials', 'execution_count': 3}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# secrets_file = open("secrets.txt","r")
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'secrets_file = open("secrets.txt","r")', 'execution_count': 4}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# string = secrets_file.read()
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'string = secrets_file.read()', 'execution_count': 5}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# secrets_dict={}
# for line in string.split('\n'):
#     if len(line) > 0:
#         #print(line.split(':'))
#         secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "secrets_dict={}\nfor line in string.split('\\n'):\n    if len(line) > 0:\n        #print(line.split(':'))\n        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()", 'execution_count': 6}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
#                                                            client_secret=secrets_dict['clientsecret']))
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],\n                                                           client_secret=secrets_dict['clientsecret']))", 'execution_count': 7}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# songs = pd.read_csv('songs.csv')
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "songs = pd.read_csv('songs.csv')", 'execution_count': 8}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# df_with_audiof = pd.read_csv('df_with_audiof.csv')
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "df_with_audiof = pd.read_csv('df_with_audiof.csv')", 'execution_count': 9}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "X = df_with_audiof[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]", 'execution_count': 10}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler().fit(X)
# X_scaled = scaler.transform(X)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler().fit(X)\nX_scaled = scaler.transform(X)', 'execution_count': 11}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# def get_cluster_from_imput(x):
#     search_results = sp.search(q=x, limit=1)
#     song_id = search_results['tracks']['items'][0]['id']
#     audio_features = sp.audio_features(song_id)
#     audio_features_df = json_normalize(audio_features)
#     X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
#     # print('X', X)
#     X_scaled = scaler.transform(X)
#     # print('X_scaled', X_scaled)
#     cluster = kmeans.predict(X_scaled)
#     return cluster[0]
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "def get_cluster_from_imput(x):\n    search_results = sp.search(q=x, limit=1)\n    song_id = search_results['tracks']['items'][0]['id']\n    audio_features = sp.audio_features(song_id)\n    audio_features_df = json_normalize(audio_features)\n    X = audio_features_df[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n                    'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]\n    # print('X', X)\n    X_scaled = scaler.transform(X)\n    # print('X_scaled', X_scaled)\n    cluster = kmeans.predict(X_scaled)\n    return cluster[0]", 'execution_count': 12}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# def pick_one_random_song(x):
#     filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]
#     random_row = filtered_df.sample(n=1, random_state=random.seed())
#     return random_row
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "def pick_one_random_song(x):\n    filtered_df = df_with_audiof[df_with_audiof['clusters'] == x]\n    random_row = filtered_df.sample(n=1, random_state=random.seed())\n    return random_row", 'execution_count': 13}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# kmeans = KMeans(n_clusters=15, random_state=42)
# kmeans.fit(X_scaled)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'kmeans = KMeans(n_clusters=15, random_state=42)  \nkmeans.fit(X_scaled)', 'execution_count': 14}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stderr', 'text': "/Users/v.adragna/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning\n  warnings.warn(\n"}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_result
# [Voila] msg_type: execute_result
# [Voila] content: {'data': {'text/plain': 'KMeans(n_clusters=15, random_state=42)', 'text/html': '<style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-color: white;}#sk-container-id-1 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-1 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-1 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-1 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-1 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-1 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-1 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-width: 100%;overflow: auto;}#sk-container-id-1 input.sk-toggleable__control:checked~label.sk-toggleable__label-arrow:before {content: "▾";}#sk-container-id-1 div.sk-estimator input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-label input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 input.sk-hidden--visually {border: 0;clip: rect(1px 1px 1px 1px);clip: rect(1px, 1px, 1px, 1px);height: 1px;margin: -1px;overflow: hidden;padding: 0;position: absolute;width: 1px;}#sk-container-id-1 div.sk-estimator {font-family: monospace;background-color: #f0f8ff;border: 1px dotted black;border-radius: 0.25em;box-sizing: border-box;margin-bottom: 0.5em;}#sk-container-id-1 div.sk-estimator:hover {background-color: #d4ebff;}#sk-container-id-1 div.sk-parallel-item::after {content: "";width: 100%;border-bottom: 1px solid gray;flex-grow: 1;}#sk-container-id-1 div.sk-label:hover label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-serial::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: 0;}#sk-container-id-1 div.sk-serial {display: flex;flex-direction: column;align-items: center;background-color: white;padding-right: 0.2em;padding-left: 0.2em;position: relative;}#sk-container-id-1 div.sk-item {position: relative;z-index: 1;}#sk-container-id-1 div.sk-parallel {display: flex;align-items: stretch;justify-content: center;background-color: white;position: relative;}#sk-container-id-1 div.sk-item::before, #sk-container-id-1 div.sk-parallel-item::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: -1;}#sk-container-id-1 div.sk-parallel-item {display: flex;flex-direction: column;z-index: 1;position: relative;background-color: white;}#sk-container-id-1 div.sk-parallel-item:first-child::after {align-self: flex-end;width: 50%;}#sk-container-id-1 div.sk-parallel-item:last-child::after {align-self: flex-start;width: 50%;}#sk-container-id-1 div.sk-parallel-item:only-child::after {width: 0;}#sk-container-id-1 div.sk-dashed-wrapped {border: 1px dashed gray;margin: 0 0.4em 0.5em 0.4em;box-sizing: border-box;padding-bottom: 0.4em;background-color: white;}#sk-container-id-1 div.sk-label label {font-family: monospace;font-weight: bold;display: inline-block;line-height: 1.2em;}#sk-container-id-1 div.sk-label-container {text-align: center;}#sk-container-id-1 div.sk-container {/* jupyter\'s `normalize.less` sets `[hidden] { display: none; }` but bootstrap.min.css set `[hidden] { display: none !important; }` so we also need the `!important` here to be able to override the default hidden behavior on the sphinx rendered scikit-learn.org. See: https://github.com/scikit-learn/scikit-learn/issues/21755 */displa ...
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# get_cluster_from_imput('When I Was Your Man')
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': "get_cluster_from_imput('When I Was Your Man')", 'execution_count': 15}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_result
# [Voila] msg_type: execute_result
# [Voila] content: {'data': {'text/plain': '1'}, 'metadata': {}, 'execution_count': 15}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# from ipywidgets import widgets
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'from ipywidgets import widgets', 'execution_count': 16}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# submit_button = widgets.Button(description="Submit")
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'submit_button = widgets.Button(description="Submit")', 'execution_count': 17}
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': '84394cb2a3534de8be46bd66f50dd848', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': '93e976961fc345e6b7083a851ec29626', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'button_color': None, 'font_weight': ''}, 'buffer_paths': []}, 'comm_id': '41f000b880ad4cde97d7797f79418e6e', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'button_color': None, 'font_weight': ''}, 'buffer_paths': []}, 'comm_id': '9ecbc02a5bc246d5b83d955b40fff7e6', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'ButtonView', 'button_style': '', 'description': 'Submit', 'disabled': False, 'icon': '', 'layout': 'IPY_MODEL_93e976961fc345e6b7083a851ec29626', 'style': 'IPY_MODEL_9ecbc02a5bc246d5b83d955b40fff7e6', 'tooltip': ''}, 'buffer_paths': []}, 'comm_id': '9defff96f9b84eaaa92089a2f595afd6', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'ButtonView', 'button_style': '', 'description': 'Submit', 'disabled': False, 'icon': '', 'layout': 'IPY_MODEL_93e976961fc345e6b7083a851ec29626', 'style': 'IPY_MODEL_9ecbc02a5bc246d5b83d955b40fff7e6', 'tooltip': ''}, 'buffer_paths': []}, 'comm_id': '96ac2f50ce2e426890d6507839f6fa4e', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# from ipywidgets import interact, widgets
# from IPython.display import Image, display
#
# max_characters = 100
# pd.set_option("display.max_colwidth", max_characters)
#
# def handle_user_input(user_input):
#     user_input = user_input.lower()
#
#     if user_input in songs['title'].values:
#         suggested_titles = songs[songs['title'] != user_input]['title']
#         if not suggested_titles.empty:
#             print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])
#     else:
#         search_results = sp.search(q=user_input, limit=10)
#         song_info = search_results['tracks']['items'][0]['artists'][0]['name']
#         print("I am going to search similar songs to " + user_input + " from " + search_results['tracks']['items'][0]['artists'][0]['name'])
#         imput_cluster = get_cluster_from_imput(user_input)
#         random_row = pick_one_random_song(imput_cluster)
#         print('You might also like ' + random_row['track.name'] + ' by ' + random_row['name'])
#         spotify_track_url = 'https://open.spotify.com/track/' + random_row['song_id']
#         print("link: ", spotify_track_url)
#         artist_info = sp.search(q=random_row['name'], type='artist', limit=1)
#         image_url = artist_info['artists']['items'][0]['images'][0]['url']
#         display(Image(url=image_url))
#
# text_input = widgets.Text(description="Search")
# text_input.layout.width = '800px'
#
# # Now import the widgets module
# from ipywidgets import widgets
#
# submit_button = widgets.Button(description="Submit")
#
# def on_submit_button_click(b):
#     user_input = text_input.value
#     handle_user_input(user_input)
#
# submit_button.on_click(on_submit_button_click)
#
# display(text_input)
# display(submit_button)
#
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: execute_input
# [Voila] content: {'code': 'from ipywidgets import interact, widgets\nfrom IPython.display import Image, display\n\nmax_characters = 100\npd.set_option("display.max_colwidth", max_characters)\n\ndef handle_user_input(user_input):\n    user_input = user_input.lower()\n    \n    if user_input in songs[\'title\'].values:\n        suggested_titles = songs[songs[\'title\'] != user_input][\'title\']\n        if not suggested_titles.empty:\n            print("You like hit songs. You might also like: " + suggested_titles.sample().values[0])\n    else:\n        search_results = sp.search(q=user_input, limit=10)\n        song_info = search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\']\n        print("I am going to search similar songs to " + user_input + " from " + search_results[\'tracks\'][\'items\'][0][\'artists\'][0][\'name\'])\n        imput_cluster = get_cluster_from_imput(user_input)\n        random_row = pick_one_random_song(imput_cluster)\n        print(\'You might also like \' + random_row[\'track.name\'] + \' by \' + random_row[\'name\'])\n        spotify_track_url = \'https://open.spotify.com/track/\' + random_row[\'song_id\']\n        print("link: ", spotify_track_url)\n        artist_info = sp.search(q=random_row[\'name\'], type=\'artist\', limit=1)\n        image_url = artist_info[\'artists\'][\'items\'][0][\'images\'][0][\'url\']\n        display(Image(url=image_url))\n\ntext_input = widgets.Text(description="Search")\ntext_input.layout.width = \'800px\' \n\n# Now import the widgets module\nfrom ipywidgets import widgets\n\nsubmit_button = widgets.Button(description="Submit")\n\ndef on_submit_button_click(b):\n    user_input = text_input.value\n    handle_user_input(user_input)\n\nsubmit_button.on_click(on_submit_button_click)\n\ndisplay(text_input)\ndisplay(submit_button)\n', 'execution_count': 18}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': '171d8e6eeafb4d13ac938a9dd6e7321c', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': '0289603006db4c68ae8992df255bf1e8', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_msg
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'DescriptionStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'description_width': ''}, 'buffer_paths': []}, 'comm_id': '3508881ec2cd439e8a569d54d98a07ee', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'DescriptionStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'description_width': ''}, 'buffer_paths': []}, 'comm_id': '5bee75748faf48218e3b96f4d461af77', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: comm_open
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: display_data
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'TextModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'TextView', 'continuous_update': True, 'description': 'Search', 'description_tooltip': None, 'disabled': False, 'layout': 'IPY_MODEL_0289603006db4c68ae8992df255bf1e8', 'placeholder': '\u200b', 'style': 'IPY_MODEL_5bee75748faf48218e3b96f4d461af77', 'value': ''}, 'buffer_paths': []}, 'comm_id': '73821038243d4a9eaf0d0672187caada', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: display_data
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'TextModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'TextView', 'continuous_update': True, 'description': 'Search', 'description_tooltip': None, 'disabled': False, 'layout': 'IPY_MODEL_0289603006db4c68ae8992df255bf1e8', 'placeholder': '\u200b', 'style': 'IPY_MODEL_5bee75748faf48218e3b96f4d461af77', 'value': ''}, 'buffer_paths': []}, 'comm_id': '7f9835a6b8b6485880fc7598d87a3002', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: comm_msg
# [Voila] content: {'data': {'method': 'update', 'state': {'width': '800px'}, 'buffer_paths': []}, 'comm_id': '0289603006db4c68ae8992df255bf1e8'}
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': '00a258b9f27a4047b22df772c6a22908', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/base', '_model_module_version': '1.2.0', '_model_name': 'LayoutModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'LayoutView', 'align_content': None, 'align_items': None, 'align_self': None, 'border': None, 'bottom': None, 'display': None, 'flex': None, 'flex_flow': None, 'grid_area': None, 'grid_auto_columns': None, 'grid_auto_flow': None, 'grid_auto_rows': None, 'grid_column': None, 'grid_gap': None, 'grid_row': None, 'grid_template_areas': None, 'grid_template_columns': None, 'grid_template_rows': None, 'height': None, 'justify_content': None, 'justify_items': None, 'left': None, 'margin': None, 'max_height': None, 'max_width': None, 'min_height': None, 'min_width': None, 'object_fit': None, 'object_position': None, 'order': None, 'overflow': None, 'overflow_x': None, 'overflow_y': None, 'padding': None, 'right': None, 'top': None, 'visibility': None, 'width': None}, 'buffer_paths': []}, 'comm_id': 'b17d05cca0204cbcbe087295f3a2d992', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'button_color': None, 'font_weight': ''}, 'buffer_paths': []}, 'comm_id': '36ae35ed52c24b2ba4166c23603dfb3a', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonStyleModel', '_view_count': None, '_view_module': '@jupyter-widgets/base', '_view_module_version': '1.2.0', '_view_name': 'StyleView', 'button_color': None, 'font_weight': ''}, 'buffer_paths': []}, 'comm_id': '3cf0e84818a3494fa510d00ca9f92276', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'ButtonView', 'button_style': '', 'description': 'Submit', 'disabled': False, 'icon': '', 'layout': 'IPY_MODEL_b17d05cca0204cbcbe087295f3a2d992', 'style': 'IPY_MODEL_3cf0e84818a3494fa510d00ca9f92276', 'tooltip': ''}, 'buffer_paths': []}, 'comm_id': '3cecc96e50ea4ec5922c38b81a881dd2', 'target_name': 'comm', 'target_module': None}
# [Voila] WARNING | No handler found for comm target 'comm'
# [Voila] msg_type: comm_open
# [Voila] content: {'data': {'state': {'_dom_classes': [], '_model_module': '@jupyter-widgets/controls', '_model_module_version': '1.5.0', '_model_name': 'ButtonModel', '_view_count': None, '_view_module': '@jupyter-widgets/controls', '_view_module_version': '1.5.0', '_view_name': 'ButtonView', 'button_style': '', 'description': 'Submit', 'disabled': False, 'icon': '', 'layout': 'IPY_MODEL_b17d05cca0204cbcbe087295f3a2d992', 'style': 'IPY_MODEL_3cf0e84818a3494fa510d00ca9f92276', 'tooltip': ''}, 'buffer_paths': []}, 'comm_id': '7806da5907c14787ba88f89c046b0fa7', 'target_name': 'jupyter.widget', 'target_module': None}
# [Voila] msg_type: display_data
# [Voila] content: {'data': {'text/plain': "Text(value='', description='Search', layout=Layout(width='800px'))", 'application/vnd.jupyter.widget-view+json': {'version_major': 2, 'version_minor': 0, 'model_id': '7f9835a6b8b6485880fc7598d87a3002'}}, 'metadata': {}, 'transient': {}}
# [Voila] msg_type: display_data
# [Voila] content: {'data': {'text/plain': "Button(description='Submit', style=ButtonStyle())", 'application/vnd.jupyter.widget-view+json': {'version_major': 2, 'version_minor': 0, 'model_id': '7806da5907c14787ba88f89c046b0fa7'}}, 'metadata': {}, 'transient': {}}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# # !pip install voila
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (busy)
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: execute_input
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'busy'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: status (idle)
# [Voila] msg_type: execute_input
# [Voila] content: {'code': '# !pip install voila', 'execution_count': 19}
# [Voila] msg_type: status
# [Voila] content: {'execution_state': 'idle'}
# [Voila] Executing cell:
# ...
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_open\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_open\\r\\n[Voila] msg_type: comm_open\\r\\n[Voila] content: {\'data\': {\'state\': {\'_model_module\': \'@jupyter-widgets/base\', \'_model_module_version\': \'1.2.0\', \'_model_name\': \'LayoutModel\', \'_view_count\': None, \'_view_module\': \'@jupyter-widgets/base\', \'_view_module_version\': \'1.2.0\', \'_view_name\': \'LayoutView\', \'align_content\': None, \'align_items\': None, \'align_self\': None, \'border\': None, \'bottom\': None, \'display\': None, \'flex\': None, \'flex_flow\': None, \'grid_area\': None, \'grid_auto_columns\': None, \'grid_auto_flow\': None, \'grid_auto_rows\': None, \'grid_column\': None, \'grid_gap\': None, \'grid_row\': None, \'grid_template_areas\': None, \'grid_template_columns\': None, \'grid_template_rows\': None, \'height\': None, \'justify_content\': None, \'justify_items\': None, \'left\': None, \'margin\': None, \'max_height\': None, \'max_width\': None, \'min_height\': None, \'min_width\': None, \'object_fit\': None, \'object_position\': None, \'order\': None, \'overflow\': None, \'overflow_x\': None, \'overflow_y\': None, \'padding\': None, \'right\': None, \'top\': None, \'visibility\': None, \'width\': None}, \'buffer_paths\': []}, \'comm_id\': \'3acba8f010e64d6abf073a8b6621c953\', \'target_name\': \'jupyter.widget\', \'target_module\': None}\\r\\n[Voila] msg_type: comm_open\\r\\n[Voila] content: {\'data\': {\'state\': {\'_model_module\': \'@jupyter-widgets/controls\', \'_model_module_version\': \'1.5.0\', \'_model_name\': \'DescriptionStyleModel\', \'_view_count\': None, \'_view_module\': \'@jupyter-widgets/base\', \'_view_module_version\': \'1.2.0\', \'_view_name\': \'StyleView\', \'description_width\': \'\'}, \'buffer_paths\': []}, \'comm_id\': \'8390af8938574996adb44138bb53ec5a\', \'target_name\': \'comm\', \'target_module\': None}\\r\\n[Voila] WARNING | No handler found for comm target \'comm\'\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_open\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_msg\\r\\n[Voila] msg_type: comm_open\\r\\n[Voila] content: {\'data\': {\'state\': {\'_model_module\': \'@jupyter-widgets/controls\', \'_model_module_version\': \'1.5.0\', \'_model_name\': \'DescriptionStyleModel\', \'_view_count\': None, \'_view_module\': \'@jupyter-widgets/base\', \'_view_module_version\': \'1.2.0\', \'_view_name\': \'StyleView\', \'description_width\': \'\'}, \'buffer_paths\': []}, \'comm_id\': \'d2a9cb4c0bb54629ae34f5ed2b5548ae\', \'target_name\': \'jupyter.widget\', \'target_module\': None}\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_open\\r\\n[Voila] msg_type: comm_open\\r\\n[Voila] content: {\'data\': {\'state\': {\'_dom_classes\': [], \'_model_module\': \'@jupyter-widgets/controls\', \'_model_module_version\': \'1.5.0\', \'_model_name\': \'TextModel\', \'_view_count\': None, \'_view_module\': \'@jupyter-widgets/controls\', \'_view_module_version\': \'1.5.0\', \'_view_name\': \'TextView\', \'continuous_update\': True, \'description\': \'Search\', \'description_tooltip\': None, \'disabled\': False, \'layout\': \'IPY_MODEL_3acba8f010e64d6abf073a8b6621c953\', \'placeholder\': \'\\\\u200b\', \'style\': \'IPY_MODEL_d2a9cb4c0bb54629ae34f5ed2b5548ae\', \'value\': \'\'}, \'buffer_paths\': []}, \'comm_id\': \'2677733c80db4bcabf3a698577316ed3\', \'target_name\': \'comm\', \'target_module\': None}\\r\\n[Voila] WARNING | No handler found for comm target \'comm\'\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: comm_open\\r\\n[Voila] msg_type: comm_open\\r\\n[Voila] content: {\'data\': {\'state\': {\'_dom_classes\': [], \'_model_module\': \'@jupyter-widgets/controls\', \'_model_module_version\': \'1.5.0\', \'_model_name\': \'TextModel\', \'_view_co ...
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': \'[Voila] msg_type: comm_open\\r\\n[Voila] content: {\\\'data\\\': {\\\'state\\\': {\\\'_dom_classes\\\': [], \\\'_model_module\\\': \\\'@jupyter-widgets/controls\\\', \\\'_model_module_version\\\': \\\'1.5.0\\\', \\\'_model_name\\\': \\\'ButtonModel\\\', \\\'_view_count\\\': None, \\\'_view_module\\\': \\\'@jupyter-widgets/controls\\\', \\\'_view_module_version\\\': \\\'1.5.0\\\', \\\'_view_name\\\': \\\'ButtonView\\\', \\\'button_style\\\': \\\'\\\', \\\'description\\\': \\\'Submit\\\', \\\'disabled\\\': False, \\\'icon\\\': \\\'\\\', \\\'layout\\\': \\\'IPY_MODEL_56dbfd5c30f746ea87ee396db82b1eba\\\', \\\'style\\\': \\\'IPY_MODEL_e6f6a4112f774babaef4223ce900dd76\\\', \\\'tooltip\\\': \\\'\\\'}, \\\'buffer_paths\\\': []}, \\\'comm_id\\\': \\\'0c35672d355849dea9c9efa1c6ece319\\\', \\\'target_name\\\': \\\'jupyter.widget\\\', \\\'target_module\\\': None}\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: status (idle)\\r\\n[Voila] msg_type: display_data\\r\\n[Voila] content: {\\\'data\\\': {\\\'text/plain\\\': "Text(value=\\\'\\\', description=\\\'Search\\\', layout=Layout(width=\\\'800px\\\'))", \\\'application/vnd.jupyter.widget-view+json\\\': {\\\'version_major\\\': 2, \\\'version_minor\\\': 0, \\\'model_id\\\': \\\'36f1d6f920f949e2807cdcc0f5dba2e4\\\'}}, \\\'metadata\\\': {}, \\\'transient\\\': {}}\\r\\n[Voila] msg_type: display_data\\r\\n[Voila] content: {\\\'data\\\': {\\\'text/plain\\\': "Button(description=\\\'Submit\\\', style=ButtonStyle())", \\\'application/vnd.jupyter.widget-view+json\\\': {\\\'version_major\\\': 2, \\\'version_minor\\\': 0, \\\'model_id\\\': \\\'0c35672d355849dea9c9efa1c6ece319\\\'}}, \\\'metadata\\\': {}, \\\'transient\\\': {}}\\r\\n[Voila] msg_type: status\\r\\n[Voila] content: {\\\'execution_state\\\': \\\'idle\\\'}\\r\\n[Voila] Executing cell:\\r\\n# !pip install voila\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: status (busy)\\r\\n\'}\r\n'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: execute_input\\r\\n[Voila] msg_type: status\\r\\n[Voila] content: {\'execution_state\': \'busy\'}\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: status (idle)\\r\\n[Voila] msg_type: execute_input\\r\\n[Voila] content: {\'code\': \'# !pip install voila\', \'execution_count\': 19}\\r\\n[Voila] msg_type: status\\r\\n[Voila] content: {\'execution_state\': \'idle\'}\\r\\n[Voila] Executing cell:\\r\\n!voila binder.ipynb --debug\\r\\n"}\r\n'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': "[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n[Voila] msg_type: stream\r\n[Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: status (busy)\\r\\n[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: execute_input\\r\\n'}\r\n"}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] msg_type: status\\r\\n[Voila] content: {\'execution_state\': \'busy\'}\\r\\n[Voila] msg_type: execute_input\\r\\n[Voila] content: {\'code\': \'!voila binder.ipynb --debug\', \'execution_count\': 20}\\r\\n"}\r\n'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: stream\\r\\n[Voila] msg_type: stream\\r\\n[Voila] content: {\'name\': \'stdout\', \'text\': \'[Voila] Looking for voila in /etc/jupyter\\\\r\\\\n[Voila] Looking for voila in /usr/local/etc/jupyter\\\\r\\\\n[Voila] Looking for voila in /Users/v.adragna/anaconda3/etc/jupyter\\\\r\\\\n[Voila] Looking for voila in /Users/v.adragna/.local/etc/jupyter\\\\r\\\\n[Voila] Looking for voila in /Users/v.adragna/.jupyter\\\\r\\\\n[Voila] Looking for voila in /Users/v.adragna/Desktop/IH-Labs/Week6/gnod_project\\\\r\\\\n[Voila] using template: lab\\\\r\\\\n[Voila] template paths:\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/voila/templates\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/nbconvert/templates\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/voila/templates\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/nbconvert/templates\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/voila/templates\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates\\\\r\\\\n\\\\t/usr/local/share/jupyter\\\\r\\\\n\\\\t/usr/local/share/jupyter/voila/templates\\\\r\\\\n\\\\t/usr/local/share/jupyter/nbconvert/templates\\\\r\\\\n\\\\t/usr/share/jupyter\\\\r\\\\n\\\\t/usr/share/jupyter/voila/templates\\\\r\\\\n\\\\t/usr/share/jupyter/nbconvert/templates\\\\r\\\\n[Voila] static paths:\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/voila/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/nbconvert/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/voila/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/nbconvert/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/voila/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/lab/static\\\\r\\\\n\\\\t/usr/local/share/jupyter/voila/templates/lab/static\\\\r\\\\n\\\\t/usr/local/share/jupyter/nbconvert/templates/lab/static\\\\r\\\\n\\\\t/usr/share/jupyter/voila/templates/lab/static\\\\r\\\\n\\\\t/usr/share/jupyter/nbconvert/templates/lab/static\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/voila/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/Library/Jupyter/nbconvert/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/voila/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/.local/share/jupyter/nbconvert/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/voila/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/share/jupyter/nbconvert/templates/base/static\\\\r\\\\n\\\\t/usr/local/share/jupyter/voila/templates/base/static\\\\r\\\\n\\\\t/usr/local/share/jupyter/nbconvert/templates/base/static\\\\r\\\\n\\\\t/usr/share/jupyter/voila/templates/base/static\\\\r\\\\n\\\\t/usr/share/jupyter/nbconvert/templates/base/static\\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/lib/python3.10/site-packages/jupyter_server/static\\\\r\\\\n[Voila] Using /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T to store connection files\\\\r\\\\n[Voila] Storing connection files in /var/folders/n7/3f1mct1521j5vz1r2r1xwby80000gn/T/voila_xzp8u_nv.\\\\r\\\\n[Voila] Serving static files from /Users/v.adragna/anaconda3/lib/python3.10/site-packages/voila/static.\\\\r\\\\n[Voila] The port 8866 is already in use, trying another port.\\ ...
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: stream\\r\\n[Voila] msg_type: stream\\r\\n[Voila] content: {\'name\': \'stdout\', \'text\': \'[Voila] The port 8867 is already in use, trying another port.\\\\r\\\\n[Voila] The port 8868 is already in use, trying another port.\\\\r\\\\n[Voila] The port 8869 is already in use, trying another port.\\\\r\\\\n[Voila] Voilà is running at:\\\\r\\\\nhttp://localhost:8870/\\\\r\\\\n\'}\\r\\n"}\r\n'}
# [Voila] activity on 0fef46d0-93b0-4b96-a271-eb66415d4de1: stream
# [Voila] msg_type: stream
# [Voila] content: {'name': 'stdout', 'text': '[Voila] activity on fed4942d-4e83-483f-94ef-04e4828f5f19: stream\r\n[Voila] msg_type: stream\r\n[Voila] content: {\'name\': \'stdout\', \'text\': "[Voila] activity on fa72f48f-9c6e-41e1-b4ac-e214107e69c1: stream\\r\\n[Voila] msg_type: stream\\r\\n[Voila] content: {\'name\': \'stdout\', \'text\': \'[Voila] WARNING | Clearing invalid/expired login cookie username-localhost-8870\\\\r\\\\n[Voila] Generating new user for token-authenticated request: 734e131ee8f9420da0578dee5d7629f1\\\\r\\\\n[Voila] Paths used for configuration of page_config: \\\\r\\\\n\\\\t/etc/jupyter/labconfig/page_config.json\\\\r\\\\n[Voila] Paths used for configuration of page_config: \\\\r\\\\n\\\\t/usr/local/etc/jupyter/labconfig/page_config.json\\\\r\\\\n[Voila] Paths used for configuration of page_config: \\\\r\\\\n\\\\t/Users/v.adragna/anaconda3/etc/jupyter/labconfig/page_config.json\\\\r\\\\n[Voila] Paths used for configuration of page_config: \\\\r\\\\n\\\\t/Users/v.adragna/.local/etc/jupyter/labconfig/page_config.json\\\\r\\\\n[Voila] Paths used for configuration of page_config: \\\\r\\\\n\\\\t/Users/v.adragna/.jupyter/labconfig/page_config.json\\\\r\\\\n\'}\\r\\n"}\r\n'}
# ^C
# [Voila] Stopping...
# [Voila] Clearing buffer for 0fef46d0-93b0-4b96-a271-eb66415d4de1
# [Voila] Kernel shutdown: 0fef46d0-93b0-4b96-a271-eb66415d4de1
